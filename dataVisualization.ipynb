# %% [markdown]
# ## 1. Tải các gói thư viện

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Đọc dữ liệu

# %%
df = pd.read_excel("C:\doAn2\data\weatherbit_hanoi_2024.xlsx")
df.head(5)
# Out:
#   Mốc thời gian  Mức độ mây che phủ  Điểm sương  Bức xạ khuếch tán ngang(DHI)  \
# 0    2023-12-31                  79        18.9                            40
# 1    2024-01-01                  59        18.1                            40
# 2    2024-01-02                  77        19.6                            40
# 3    2024-01-03                  80        15.4                            40
# 4    2024-01-04                 100        14.0                            40
#
#    Bức xạ trực tiếp bình thường(DNI)  Bức xạ mặt trời toàn phần ngang(GHI)  \
# 0                                329                                   207
# 1                                329                                   207
# 2                                329                                   208
# 3                                329                                   208
# 4                                330                                   209
#
#    max_dhi  max_dni  max_ghi  Bức xạ mặt trời tổng  ...  \
# 0      116      911      764                    78  ...
# 1      116      912      764                   189  ...
# 2      116      912      765                   149  ...
# 3      116      912      767                    50  ...
# 4      116      913      768                    69  ...
#
#    Thời điểm có hướng gió mạnh nhất  Hướng gió hiện tại  Tốc độ gió giật  \
# 0                        1704006000                 155              3.6
# 1                        1704042000                 135              7.6
# 2                        1704196800                 135              7.4
# 3                        1704261600                 186             10.4
# 4                        1704337200                 197              6.0
#
#    Tốc độ gió trung bình  Lượng mưa ghi nhận  Lượng mưa từ nguồn vệ tinh GPM  \
# 0                    0.9                 0.0                             0.0
# 1                    1.6                 0.0                             0.0
# 2                    1.4                 0.0                             0.0
# 3                    1.8                 0.0                             0.0
# 4                    1.4                 0.0                             0.0
#
#    Áp suất không khí  Độ ẩm tương đối  Áp suất mặt biển chuẩn  \
# 0               1016               82                    1017
# 1               1015               79                    1017
# 2               1015               81                    1016
# 3               1018               79                    1019
# 4               1018               71                    1019
#
#    Trạng thái cập nhật dữ liệu
# 0                        final
# 1                        final
# 2                        final
# 3                        final
# 4                        final
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 3. Tiền xử lý dữ liệu

# %%
df.shape
# Out:
# (365, 34)

# %%
df.dtypes
# Out:
# Mốc thời gian                                           datetime64[ns]
# Mức độ mây che phủ                                               int64
# Điểm sương                                                     float64
# Bức xạ khuếch tán ngang(DHI)                                     int64
# Bức xạ trực tiếp bình thường(DNI)                                int64
# Bức xạ mặt trời toàn phần ngang(GHI)                             int64
# max_dhi                                                          int64
# max_dni                                                          int64
# max_ghi                                                          int64
# Bức xạ mặt trời tổng                                             int64
# Giá trị dự đoán bức xạ khuếch tán ngang(DHI)                     int64
# Giá trị dự đoán bức xạ trực tiếp bình thường(DNI)                int64
# Giá trị dự đoán bức xạ mặt trời toàn phần ngang(GHI)             int64
# Giá trị dự đoán bức xạ mặt trời tổng                             int64
# Nhiệt  độ cao nhất                                             float64
# Thời điểm nhiệt độ cao nhất                                      int64
# Nhiệt độ thấp nhất                                             float64
# Thời điểm nhiệt độ thấp nhất                                     int64
# Nhiệt độ hiện tại                                              float64
# Thời điểm ghi nhận nhiệt độ hiện tại                             int64
# Nhiệt độ trung bình                                            float64
# Cường độ tia UV max                                            float64
# Tốc độ gió lớn nhất                                            float64
# Hướng gió tại thời điểm gió mạnh nhất                            int64
# Thời điểm có hướng gió mạnh nhất                                 int64
# Hướng gió hiện tại                                               int64
# Tốc độ gió giật                                                float64
# Tốc độ gió trung bình                                          float64
# Lượng mưa ghi nhận                                             float64
# Lượng mưa từ nguồn vệ tinh GPM                                 float64
# Áp suất không khí                                                int64
# Độ ẩm tương đối                                                  int64
# Áp suất mặt biển chuẩn                                           int64
# Trạng thái cập nhật dữ liệu                                     object
# dtype: object

# %%
df.describe()
# Out:
#                        Mốc thời gian  Mức độ mây che phủ  Điểm sương  \
# count                            365          365.000000  365.000000
# mean   2024-06-30 22:05:35.342465792           70.284932   21.291233
# min              2023-12-31 00:00:00            0.000000    3.300000
# 25%              2024-04-01 00:00:00           56.000000   18.200000
# 50%              2024-07-01 00:00:00           75.000000   23.300000
# 75%              2024-09-30 00:00:00           90.000000   25.800000
# max              2024-12-30 00:00:00          100.000000   28.300000
# std                              NaN           24.795336    5.539457
#
#        Bức xạ khuếch tán ngang(DHI)  Bức xạ trực tiếp bình thường(DNI)  \
# count                    365.000000                         365.000000
# mean                      47.484932                         378.539726
# min                       40.000000                         326.000000
# 25%                       43.000000                         348.000000
# 50%                       48.000000                         382.000000
# 75%                       52.000000                         412.000000
# max                       53.000000                         419.000000
# std                        4.778951                          32.745551
#
#        Bức xạ mặt trời toàn phần ngang(GHI)     max_dhi     max_dni  \
# count                            365.000000  365.000000  365.000000
# mean                             289.800000  123.542466  935.021918
# min                              205.000000  115.000000  909.000000
# 25%                              241.000000  120.000000  928.000000
# 50%                              304.000000  126.000000  937.000000
# 75%                              339.000000  126.000000  942.000000
# max                              346.000000  128.000000  956.000000
# std                               50.541257    4.083803   13.226869
#
#            max_ghi  Bức xạ mặt trời tổng  ...  \
# count   365.000000            365.000000  ...
# mean    955.005479            146.030137  ...
# min     757.000000             21.000000  ...
# 25%     854.000000             75.000000  ...
# 50%    1007.000000            120.000000  ...
# 75%    1050.000000            211.000000  ...
# max    1062.000000            337.000000  ...
# std     109.123732             84.634519  ...
#
#        Hướng gió tại thời điểm gió mạnh nhất  \
# count                             365.000000
# mean                              180.342466
# min                                50.000000
# 25%                               140.000000
# 50%                               161.000000
# 75%                               216.000000
# max                               348.000000
# std                                62.289738
#
#        Thời điểm có hướng gió mạnh nhất  Hướng gió hiện tại  Tốc độ gió giật  \
# count                      3.650000e+02          365.000000       365.000000
# mean                       1.719804e+09          180.342466         7.273699
# min                        1.704006e+09           50.000000         2.800000
# 25%                        1.711969e+09          140.000000         6.000000
# 50%                        1.719803e+09          161.000000         7.200000
# 75%                        1.727669e+09          216.000000         8.400000
# max                        1.735538e+09          348.000000        25.600000
# std                        9.125741e+06           62.289738         2.019144
#
#        Tốc độ gió trung bình  Lượng mưa ghi nhận  \
# count             365.000000          365.000000
# mean                1.576164            6.732603
# min                 0.600000            0.000000
# 25%                 1.200000            0.000000
# 50%                 1.500000            0.500000
# 75%                 1.800000            6.500000
# max                 5.600000          114.500000
# std                 0.511147           14.651250
#
#        Lượng mưa từ nguồn vệ tinh GPM  Áp suất không khí  Độ ẩm tương đối  \
# count                      365.000000         365.000000       365.000000
# mean                         6.732603        1009.608219        79.364384
# min                          0.000000         992.000000        52.000000
# 25%                          0.000000        1004.000000        75.000000
# 50%                          0.500000        1009.000000        81.000000
# 75%                          6.500000        1015.000000        85.000000
# max                        114.500000        1028.000000        95.000000
# std                         14.651250           7.099949         8.757185
#
#        Áp suất mặt biển chuẩn
# count              365.000000
# mean              1010.509589
# min                993.000000
# 25%               1004.000000
# 50%               1010.000000
# 75%               1016.000000
# max               1029.000000
# std                  7.123560
#
# [8 rows x 33 columns]

# %%
print('Null Values =', df.isnull().values.any())
# Out:
# Null Values = False

# %% [markdown]
# ## 4. Trực quan hóa dữ liệu

# %% [markdown]
# ### 4.1. Biểu đồ xu hướng

# %%
df['Mốc thời gian'] = pd.to_datetime(df['Mốc thời gian'], errors='coerce')

columns_to_plot = [
    "Nhiệt độ trung bình",
    "Điểm sương",
    "Độ ẩm tương đối",
    "Áp suất không khí",
    "Tốc độ gió trung bình",
    "Lượng mưa ghi nhận",
    "Bức xạ mặt trời toàn phần ngang(GHI)",
    "Mức độ mây che phủ"
]

sns.set(style="whitegrid")
palette = sns.color_palette("husl", len(columns_to_plot))
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(20, 14))
axes = axes.flatten()

for i, col in enumerate(columns_to_plot):
    ax = axes[i]
    sns.lineplot(data=df, x='Mốc thời gian', y=col, ax=ax, color=palette[i], linewidth=1.8)

    ax.set_title(col.replace('_', ' ').title(), fontsize=12, fontweight='bold')
    ax.set_xlabel('')
    ax.set_ylabel('')
    
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
    ax.tick_params(axis='x', rotation=45)

if len(columns_to_plot) < len(axes):
    fig.delaxes(axes[-1])

plt.suptitle('Xu hướng các yếu tố thời tiết Hà Nội trong năm 2024', fontsize=22, fontweight='bold', y=1.02, color='brown')
plt.tight_layout()
plt.subplots_adjust(top=0.93)
plt.show()

# %% [markdown]
# ### 4.2. Biểu đồ nhiệt

# %%
df['tháng'] = df['Mốc thời gian'].dt.month
df['ngày'] = df['Mốc thời gian'].dt.day


pivot_rain = df.pivot_table(index='ngày', columns='tháng', values='Lượng mưa ghi nhận', aggfunc='mean')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_rain, cmap='Blues', linewidths=0.5, linecolor='gray')
plt.title('Bản Đồ Nhiệt: Lượng Mưa Theo Ngày & Tháng – Hà Nội 2024', fontsize=14)
plt.xlabel('Tháng')
plt.ylabel('Ngày')
plt.show()

# %% [markdown]
# ### 4.3. Ma trận tương quan

# %%
col = [
    "Điểm sương",
    "Áp suất không khí",
    "Áp suất mặt biển chuẩn",
    "Nhiệt độ trung bình",
    "Bức xạ mặt trời toàn phần ngang(GHI)",
    "Bức xạ mặt trời tổng",
    "Lượng mưa từ nguồn vệ tinh GPM",
    "Bức xạ khuếch tán ngang(DHI)",
    "Bức xạ trực tiếp bình thường(DNI)",
    "Mức độ mây che phủ",
    "Hướng gió tại thời điểm gió mạnh nhất",
    "Tốc độ gió trung bình",
    "Tốc độ gió giật",
    "Độ ẩm tương đối",
    "Cường độ tia UV max"
]


# Lọc DataFrame chỉ lấy các cột thuộc features và targets
df_corr = df[col]

# Tính ma trận tương quan giữa tất cả các biến
corr_matrix = df_corr.corr()

# Lấy ma trận tương quan giữa biến phụ thuộc (targets) và biến độc lập (features)
corr_submatrix = corr_matrix.loc[col]

# Vẽ heatmap ma trận tương quan này
plt.figure(figsize=(10, 6))
sns.heatmap(corr_submatrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Ma trận tương quan giữa biến phụ thuộc và biến độc lập', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### 4.4. Biểu đồ phân tán

# %%
# chọn cột
col = [
    "Điểm sương",
    "Nhiệt độ trung bình",
    "Lượng mưa ghi nhận",
    "Tốc độ gió trung bình",
    "Độ ẩm tương đối",
]

# trích xuất + làm sạch dữ liệu
df_selected = df[col].copy()
df_selected = df_selected.select_dtypes(include=["number"])
df_selected = df_selected.dropna()

# vẽ biểu đồ phân tán
g = sns.pairplot(df_selected, corner=True, plot_kws={'alpha': 1.0, 's': 10})

for ax in g.axes.flat:
    if ax is not None:
        ax.set_xlabel(ax.get_xlabel(), fontsize=14)
        ax.set_ylabel(ax.get_ylabel(), fontsize=14)

plt.suptitle("Biểu đồ phân tán dữ liệu", fontsize=30, y=1, color='black', fontweight='bold')
plt.tight_layout()
plt.show()
